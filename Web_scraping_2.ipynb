# %%
import pandas as pd

# %%
url="https://en.wikipedia.org/wiki/Lionel_Messi"

# %%
table=pd.read_html(url)
len(table)
# Out:
# 65

# %%
matching_tables=pd.read_html(url,match='Goals')
len(matching_tables)
# Out:
# 2

# %%
matching_tables[0]
# Out:
#               0                   1                   2             3   \
# 0           Club              Season              League  Copa del Rey
# 1       Division                Apps               Goals          Apps
# 2    Barcelona C        2003–04[496]    Tercera División            10
# 3    Barcelona B         2003–04[39]  Segunda División B             5
# 4    2004–05[40]  Segunda División B                  17             6
# 5          Total                  22                   6             —
# 6      Barcelona         2004–05[40]             La Liga             7
# 7    2005–06[54]             La Liga                  17             6
# 8    2006–07[57]             La Liga                  26            14
# 9    2007–08[72]             La Liga                  28            10
# 10   2008–09[80]             La Liga                  31            23
# 11   2009–10[93]             La Liga                  35            34
# ...
